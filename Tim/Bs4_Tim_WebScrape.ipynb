# %% [markdown]
# ### BeautifulSoup -
# Beautiful Soup is a Python library for pulling data out of HTML and XML files. It works with your favorite parser to provide idiomatic ways of navigating, searching, and modifying the parse tree. It commonly saves programmers hours or days of work.
#
# #### !pip install beautifulsoup4
#
#
# They also suggest using the lxml parser
#
# parse - resolve (a sentence) into its component parts and describe their syntactic roles.
# #### !pip install lxml

# %%
from bs4 import BeautifulSoup

# %%
with open ('index.html', 'r') as f:
    doc = BeautifulSoup(f, "html.parser")
    
    
print(doc.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    Your Title Here
#   </title>
#  </head>
#  <body bgcolor="FFFFFF">
#   <center>
#    <img align="BOTTOM" src="clouds.jpg"/>
#   </center>
#   <hr/>
#   <a href="http://somegreatsite.com">
#    Link Name
#   </a>
#   is a link to another nifty site
#   <h1>
#    This is a Header
#   </h1>
#   <h2>
#    This is a Medium Header
#   </h2>
#   Send me mail at
#   <a href="mailto:support@yourcompany.com">
#    support@yourcompany.com
#   </a>
#   .
#   <p>
#    This is a new paragraph!
#    <p>
#     <b color="red">
#      This is a new paragraph!
#     </b>
#     <br/>
#     <b>
#      <i>
#       This is a new sentence without a paragraph break, in bold italics.
#      </i>
#     </b>
#     <hr/>
#    </p>
#   </p>
#  </body>
# </html>

# %% [markdown]
# ### Get tag...

# %%
tag = doc.title
print(tag)
# Out:
# <title>Your Title Here</title>

# %%
# tag string
print(tag.string)
# Out:
# Your Title Here

# %% [markdown]
# ### Modify the tag.......inplace

# %%
tag.string = "Modified Title"

print(tag)
# Out:
# <title>Modified Title</title>

# %%
print(doc.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    Modified Title
#   </title>
#  </head>
#  <body bgcolor="FFFFFF">
#   <center>
#    <img align="BOTTOM" src="clouds.jpg"/>
#   </center>
#   <hr/>
#   <a href="http://somegreatsite.com">
#    Link Name
#   </a>
#   is a link to another nifty site
#   <h1>
#    This is a Header
#   </h1>
#   <h2>
#    This is a Medium Header
#   </h2>
#   Send me mail at
#   <a href="mailto:support@yourcompany.com">
#    support@yourcompany.com
#   </a>
#   .
#   <p>
#    This is a new paragraph!
#    <p>
#     <b color="red">
#      This is a new paragraph!
#     </b>
#     <br/>
#     <b>
#      <i>
#       This is a new sentence without a paragraph break, in bold italics.
#      </i>
#     </b>
#     <hr/>
#    </p>
#   </p>
#  </body>
# </html>

# %% [markdown]
# ### Get all p tags

# %%
tags = doc.find_all('p')

print(tags)
# Out:
# [<p> This is a new paragraph!
#
# <p> <b color="red">This is a new paragraph!</b>
# <br/> <b><i>This is a new sentence without a paragraph break, in bold italics.</i></b>
# <hr/>
# </p></p>, <p> <b color="red">This is a new paragraph!</b>
# <br/> <b><i>This is a new sentence without a paragraph break, in bold italics.</i></b>
# <hr/>
# </p>]

# %% [markdown]
# ### Get b tag of first p tag...

# %%
tags = doc.find_all('p')[0]

print(tags.find_all('b'))
# Out:
# [<b color="red">This is a new paragraph!</b>, <b><i>This is a new sentence without a paragraph break, in bold italics.</i></b>]

# %% [markdown]
# ## Install requests...

# %%
import requests

url = 'https://www.newegg.ca/gigabyte-geforce-rtx-3080-ti-gv-n308tgaming-oc-12gd/p/N82E16814932436?Description=3080&cm_re=3080-_-14-932-436-_-Product'

result = requests.get(url).text

print(result)

# %%
doc = BeautifulSoup(result, 'html.parser')

print(doc.prettify())

# %% [markdown]
# #### Context -
# We are trying to scrape the GPU price

# %% [markdown]
# ## Find specific text...

# %%
prices = doc.find_all(text = "$")
print(prices)
# Out:
# ['$', '$', '$']

# %% [markdown]
# ## Find the parent tag of the specific text...

# %%
parent = prices[0].parent

print(parent)
# Out:
# <li class="price-current"><span class="price-current-label"></span>$<strong>2,898</strong><sup>.00</sup></li>

# %% [markdown]
# ### Notice that the price is inside the strong tag...

# %%
strong = parent.find("strong")

print(strong)
print(strong.text)
print(strong.string)
# Out:
# <strong>2,898</strong>
# 2,898
# 2,898

# %% [markdown]
# ----

# %% [markdown]
# # Searching and Filtering

# %%
from bs4 import BeautifulSoup

with open ('index2.html', 'r') as f:
    doc = BeautifulSoup(f, 'html.parser')
    
# print(doc.prettify())

# %% [markdown]
# ### Access attributes...

# %%
tag = doc.find('option')

print(tag)
# Out:
# <option selected="" value="course-type">Course type*</option>

# %% [markdown]
# ### How to change the value of the value attribute...

# %%
tag['value'] = 'NewVal'

print(tag)
# Out:
# <option selected="" value="NewVal">Course type*</option>

# %% [markdown]
# ### Add Attributes...

# %%
tag['color'] = 'blue'

print(tag)
# Out:
# <option color="blue" selected="" value="NewVal">Course type*</option>

# %% [markdown]
# ### Show all attributes

# %%
print(tag.attrs)
# Out:
# {'value': 'NewVal', 'selected': '', 'color': 'blue'}

# %% [markdown]
# ### Find Multiple tags

# %%
tags = doc.find_all(['p', 'div', 'li'])

print(tags)

# %% [markdown]
# ### Find tags with specific attributes

# %%
tags = doc.find_all(['option'], text = "Undergraduate")

print(tags)
# Out:
# [<option value="undergraduate">Undergraduate</option>]

# %%
tags = doc.find_all(['option'], text = "Undergraduate", value = 'undergraduate')

print(tags)
# Out:
# [<option value="undergraduate">Undergraduate</option>]

# %%
tags = doc.find_all(['option'], text = "Undergraduate", value = 'under')

print(tags)
# Out:
# []

# %% [markdown]
# ### Find tags based on class

# %%
tags = doc.find_all(class_ = 'btn-item')

print(tags)
# Out:
# [<a class="btn-item" href="https://www.w3docs.com/learn-html.html">Learn HTML</a>, <a class="btn-item" href="https://www.w3docs.com/quiz/#">Select Quiz</a>]

# %% [markdown]
# ### Using Regular Expressions

# %%
import re

tags = doc.find_all(text = re.compile('\$.*'))

print(tags,'\n')

for tag in tags:
    print(tag.strip())
# Out:
# ['\n        $2345\n      ', '\n        $123\n        ']
#
# $2345
# $123

# %% [markdown]
# ### Limiting responses

# %%
tags = doc.find_all(text = re.compile('\$.*'), limit = 1)

print(tags,'\n')

for tag in tags:
    print(tag.strip())
# Out:
# ['\n        $2345\n      ']
#
# $2345

# %% [markdown]
# ---

# %% [markdown]
# # Navigating the HTML tree

# %%
url = 'https://coinmarketcap.com/'

result = requests.get(url).text

doc = BeautifulSoup(result, 'html.parser')

# %%
tbody = doc.tbody

print(tbody)

# %% [markdown]
# ### Iterate over sibling tags

# %%
trs = tbody.contents # Gives a list of all the tags that are inside the table body

print(trs)

# %% [markdown]
# ### .next_sibling

# %%
print(trs[0].next_sibling) # table row after the first...

# %% [markdown]
# ### .previous_sibling

# %%
print(trs[1].previous_sibling)

# %% [markdown]
# ### next_siblings

# %%
# next_siblings will return a generator object that you can iterate through
print(trs[0].next_siblings, '\n\n')

list(trs[0].next_siblings)

# %% [markdown]
# ### .parent

# %%
# .parent will return the parent tag.....in this case the entire tbody tag
print(trs[0].parent, '\n------------\n----------\n------------\n')

print(trs[0].parent.name)

# %% [markdown]
# ## Context -
# Getting all the Crypto names and prices

# %%
tbody = doc.tbody

trs = tbody.contents

# %%
prices = {}

for tr in trs[:10]:
#     print('\n'*3)
    name, price = tr.contents[2:4]  # all table data inside the row...
    fixed_name = name.p.text
    fixed_price = price.a.text
    
    prices[fixed_name] = fixed_price
    
    
print(prices)
# Out:
# {'Bitcoin': '$42,781.95', 'Ethereum': '$3,064.18', 'Tether': '$1.00', 'BNB': '$427.20', 'USD Coin': '$1.00', 'Cardano': '$1.17', 'Solana': '$118.64', 'XRP': '$0.7237', 'Terra': '$56.80', 'Polkadot': '$22.20'}

# %% [markdown]
# ---

# %% [markdown]
# # Finding the best GPU prices...

# %%
from bs4 import BeautifulSoup
import requests
import re

# %%
search_term = input("Product...? ")
# https://www.newegg.ca/p/pl?d=3080
url = f"https://www.newegg.ca/p/pl?d={search_term}"

page = requests.get(url).text

doc = BeautifulSoup(page, 'html.parser')
# Out:
# Product...? 3080

# %% [markdown]
# ### Get number of pages

# %%
page_text = doc.find(class_ = "list-tool-pagination-text")

pages = int(page_text.text[4:].split('/')[1])

print(pages)
# Out:
# 6

# %% [markdown]
# ### Now you want to loop through all the pages...

# %%
items_found = {}


for page in range(1, pages+1):

    url = f"https://www.newegg.ca/p/pl?d={search_term}&page={page}"
    page = requests.get(url).text
    doc = BeautifulSoup(page, 'html.parser')
    div = doc.find(class_ = 'item-cells-wrap border-cells items-grid-view four-cells expulsion-one-cell')
    
    items = div.find_all(text = re.compile(search_term)) # usign re so that we match non-exact matches...
    for item in items:
        parent = item.parent
        
        if parent.name != 'a':
            continue
        
        link = parent['href']
        
        next_parent = item.find_parent( class_= 'item-container')
        
        price = next_parent.find(class_='price-current').strong#.string
        
        if price == None:
            continue

        price = price.text
        
        items_found[item] = {'price': int(price.replace(',', '')), 'link':link}
        
sorted_items = sorted(items_found.items(), key = lambda x: x[1]['price'])  # returns a tuple..

for item in sorted_items:
    print(item[0])
    print(f"${item[1]['price']}")
    print(item[1]['link'])
    print('\n'*5)
# Out:
# GIGABYTE Eagle GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 ATX Video Card GV-N3080EAGLE-10GD (rev. 2.0) (LHR)
# $1299
# https://www.newegg.ca/gigabyte-geforce-rtx-3080-gv-n3080eagle-10gd/p/N82E16814932461?Description=3080&cm_re=3080-_-14-932-461-_-Product
#
#
#
#
#
#
# ASUS TUF Gaming NVIDIA GeForce RTX 3080 V2 OC Edition Graphics Card (PCIe 4.0, 10GB GDDR6X, LHR, HDMI 2.1, DisplayPort 1.4a, Dual Ball Fan Bearings, Military-grade Certification, GPU Tweak II)
# $1399
# https://www.newegg.ca/asus-geforce-rtx-3080-tuf-rtx3080-o10g-v2-gaming/p/N82E16814126525?Description=3080&cm_re=3080-_-14-126-525-_-Product
#
#
#
#
#
#
# ASUS ROG Strix GeForce RTX 3080 V2 OC Edition 10GB GDDR6X PCI Express 4.0 x16 Video Card ROG-STRIX-RTX3080-O10G-V2-GAMING (LHR)
# $1399
# https://www.newegg.ca/asus-geforce-rtx-3080-strix-rtx3080-o10g-v2-gaming/p/N82E16814126534?Description=3080&cm_re=3080-_-14-126-534-_-Product
#
#
#
#
#
#
# ASUS ROG STRIX GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 x16 ATX Video Card ROG-STRIX-RTX3080-O10G-WHITE-V2 (LHR)
# $1499
# https://www.newegg.ca/asus-geforce-rtx-3080-rtx3080-o10g-wht-v2/p/N82E16814126533?Description=3080&cm_re=3080-_-14-126-533-_-Product
#
#
#
#
#
#
# GIGABYTE Gaming OC GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 ATX Video Card GV-N3080GAMING OC-10GD (rev. 2.0) (LHR) and GIGABYTE B550 AORUS ELITE AM4 AMD B550 ATX Motherboard with Dual M.2 SATA 6Gb/s USB 3.2 Gen 2 2.5 GbE LAN PCIe 4.0 an
# $1818
# https://www.newegg.ca/Product/ComboDealDetails?ItemList=Combo.4452438
#
#
#
#
#
#
# GIGABYTE Gaming OC GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 ATX Video Card GV-N3080GAMING OC-10GD (rev. 2.0) (LHR) and GIGABYTE B550 AORUS PRO AC AM4 AMD B550 ATX Motherboard with Dual M.2 SATA 6Gb/s USB 3.2 Gen 2 Intel 802.11ac 2.5 GbE
# $1869
# https://www.newegg.ca/Product/ComboDealDetails?ItemList=Combo.4452440
#
#
#
#
#
#
# MSI Gaming GeForce RTX 3080 12GB GDDR6X PCI Express 4.0 ATX Video Card RTX 3080 GAMING Z TRIO 12G LHR
# $1899
# https://www.newegg.ca/msi-geforce-rtx-3080-rtx-3080-gaming-z-trio-12g-lhr/p/N82E16814137711?Description=3080&cm_re=3080-_-14-137-711-_-Product
#
#
#
#
#
#
# MSI Gaming GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 ATX Video Card RTX 3080 GAMING Z TRIO 10G LHR
# $1949
# https://www.newegg.ca/p/1FT-0009-008V8?Description=3080&cm_re=3080-_-9SIAPBWGW64240-_-Product
#
#
#
#
#
#
# GIGABYTE Gaming OC GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 ATX Video Card GV-N3080GAMING OC-10GD (rev. 2.0) (LHR) and GIGABYTE X570S AERO G AM4 AMD X570 SATA 6Gb/s ATX AMD Motherboard and Rosewill Hive Series 850W Full Modular Gaming P
# $2038
# https://www.newegg.ca/Product/ComboDealDetails?ItemList=Combo.4452436
#
#
#
#
#
#
# GIGABYTE Gaming OC GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 ATX Video Card GV-N3080GAMING OC-10GD (rev. 2.0) (LHR)
# $2084
# https://www.newegg.ca/gigabyte-geforce-rtx-3080-gv-n3080gaming-oc-10gd/p/N82E16814932459?Description=3080&cm_re=3080-_-14-932-459-_-Product
#
#
#
#
#
#
# GIGABYTE GeForce RTX 3080 GAMING OC 10GB Video Card, GV-N3080GAMING OC-10GD
# $2108
# https://www.newegg.ca/gigabyte-geforce-rtx-3080-gv-n3080gaming-oc-10gd/p/N82E16814932329?Description=3080&cm_re=3080-_-9SIAVT9H3M8413-_-Product
#
#
#
#
#
#
# MSI Ventus GeForce RTX 3080 PCI Express 4.0 Video Card RTX 3080 VENTUS 3X PLUS 10G OC LHR
# $2114
# https://www.newegg.ca/msi-geforce-rtx-3080-rtx-3080-ventus-3x-plus-10g-oc-lhr/p/N82E16814137686?Description=3080&cm_re=3080-_-14-137-686-_-Product
#
#
#
#
#
#
# GIGABYTE GeForce RTX 3080 VISION OC 10GB Video Card, GV-N3080VISION OC-10GD
# $2138
# https://www.newegg.ca/gigabyte-geforce-rtx-3080-gv-n3080vision-oc-10gd/p/N82E16814932337?Description=3080&cm_re=3080-_-9SIAVT9H3M8414-_-Product
#
#
#
#
#
#
# MSI Ventus GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 Video Card RTX 3080 VENTUS 3X 10G OC LHR
# $2148
# https://www.newegg.ca/p/1FT-0009-006M5?Description=3080&cm_re=3080-_-1FT-0009-006M5-_-Product
#
#
#
#
#
#
# GIGABYTE Eagle GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 ATX Video Card GV-N3080EAGLE-10GD (rev. 2.0) and GIGABYTE Z590 AORUS ELITE AX LGA 1200 Intel Z590 ATX Motherboard with Triple M.2 PCIe 4.0 USB 3.2 Gen2X2 Type-C Intel WIFI 6 2.5GbE
# $2189
# https://www.newegg.ca/Product/ComboDealDetails?ItemList=Combo.4343637
#
#
#
#
#
#
# GIGABYTE Eagle GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 ATX Video Card GV-N3080EAGLE-10GD (rev. 2.0) and AMD Ryzen 9 5950X - Ryzen 9 5000 Series Vermeer (Zen 3) 16-Core 3.4 GHz Socket AM4 105W Desktop Processor - 100-100000059WOF
# $2214
# https://www.newegg.ca/Product/ComboDealDetails?ItemList=Combo.4345259
#
#
#
#
#
#
# GIGABYTE Vision OC GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 ATX Video Card GV-N3080VISION OC-10GD (rev. 2.0) (LHR)
# $2243
# https://www.newegg.ca/p/1FT-000A-002M3?Description=3080&cm_re=3080-_-9SIAGYBGK03165-_-Product
#
#
#
#
#
#
# MSI Suprim GeForce RTX 3080 10GB GDDR6X Video Card RTX 3080 SUPRIM X 10G LHR
# $2280
# https://www.newegg.ca/p/1FT-0009-006H1?Description=3080&cm_re=3080-_-1FT-0009-006H1-_-Product
#
#
#
#
#
#
# MSI Gaming GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 ATX Video Card RTX 3080 GAMING Z TRIO 10G
# $2288
# https://www.newegg.ca/msi-geforce-rtx-3080-gaming-z-trio-10g/p/N82E16814137652?Description=3080&cm_re=3080-_-14-137-652-_-Product
#
#
#
#
#
#
# MSI Gaming GeForce RTX 3080 10GB Video Card RTX 3080 GAMING TRIO PLUS 10G LHR
# $2298
# https://www.newegg.ca/msi-3080-gaming-trio-plus/p/1FT-0009-008U6?Description=3080&cm_re=3080-_-9SIAVH1HG51638-_-Product
#
#
#
#
#
#
# MSI Ventus GeForce RTX 3080 PCI Express 4.0 Video Card RTX 3080 VENTUS 3X PLUS 10G OC LHR and AMD Ryzen 7 5800X - Ryzen 7 5000 Series Vermeer (Zen 3) 8-Core 3.8 GHz Socket AM4 105W Desktop Processor - 100-100000063WOF and MSI MPG X570 GAMIN
# $2364
# https://www.newegg.ca/Product/ComboDealDetails?ItemList=Combo.4350801
#
#
#
#
#
#
# MSI Suprim GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 Video Card RTX 3080 SUPRIM X 10G
# $2398
# https://www.newegg.ca/msi-geforce-rtx-3080-rtx3080-suprim-x-10g/p/N82E16814137609?Description=3080&cm_re=3080-_-14-137-609-_-Product
#
#
#
#
#
#
# GAINWARD GeForce RTX 3080  Glare G Edition Gaming Graphics Card (PCIe 4.0, 10GB GDDR6X, HDMI 2.1, 320bit, 1710MHz)
# $2399
# https://www.newegg.ca/gainward-ga102-202/p/27N-0075-00017?Description=3080&cm_re=3080-_-27N-0075-00017-_-Product
#
#
#
#
#
#
# GIGABYTE Vision GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 ATX Video Card GV-N308TVISION OC-12GD and CORSAIR RMx Series (2021) RM1000x CP-9020201-NA 1000 W ATX12V / EPS12V SLI Ready CrossFire Ready 80 PLUS GOLD Certified Full Modular A
# $2399
# https://www.newegg.ca/Product/ComboDealDetails?ItemList=Combo.4452200
#
#
#
#
#
#
# ASUS ROG Strix GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 Video Card ROG-STRIX-RTX3080-10G-GAMING
# $2405
# https://www.newegg.ca/asus-geforce-rtx-3080-rog-strix-rtx3080-10g-gaming/p/N82E16814126469?Description=3080&cm_re=3080-_-9SIAVT9HA37549-_-Product
#
#
#
#
#
#
# EVGA GeForce RTX 3080 12GB GDDR6X PCI Express 4.0 ATX Video Card 12G-P5-4877-KL
# $2470
# https://www.newegg.ca/evga-geforce-rtx-3080-12g-p5-4877-kl/p/N82E16814487553?Description=3080&cm_re=3080-_-14-487-553-_-Product
#
#
#
#
#
#
# EVGA GeForce RTX 3080 Ti XC3 ULTRA GAMING Video Card, 12G-P5-3955-KR, 12GB GDDR6X, iCX3 Cooling, ARGB LED, Metal Backplate
# $2486
# https://www.newegg.ca/evga-geforce-rtx-3080-ti-12g-p5-3955-kr/p/N82E16814487548?Description=3080&cm_re=3080-_-9SIB277FJW6924-_-Product
#
#
#
#
#
#
# GIGABYTE Vision GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 x16 ATX Video Card GV-N308TVISION OC-12GD
# $2494
# https://www.newegg.ca/p/1FT-000A-002A5?Description=3080&cm_re=3080-_-9SIAGYBGM24562-_-Product
#
#
#
#
#
#
# GIGABYTE Eagle GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 ATX Video Card GV-N308TEAGLE OC-12GD
# $2553
# https://www.newegg.ca/gigabyte-geforce-rtx-3080-ti-gv-n308teagle-oc-12gd/p/N82E16814932438?Description=3080&cm_re=3080-_-9SIAGYBEWR1904-_-Product
#
#
#
#
#
#
# ZOTAC Trinity OC GeForce RTX 3080 12GB GDDR6X PCI Express 4.0 ATX Video Card ZT-A30820J-10PLHR
# $2599
# https://www.newegg.ca/zotac-geforce-rtx-3080-zt-a30820j-10plhr/p/N82E16814500526?Description=3080&cm_re=3080-_-9SIADGEGW21420-_-Product
#
#
#
#
#
#
# GIGABYTE Eagle GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 ATX Video Card GV-N308TEAGLE-12GD
# $2659
# https://www.newegg.ca/gigabyte-geforce-rtx-3080-ti-gv-n308teagle-12gd/p/N82E16814932439?Description=3080&cm_re=3080-_-9SIAGYBGGM5798-_-Product
#
#
#
#
#
#
# ASUS ROG Strix GeForce RTX 3080 V2 OC Edition 10GB GDDR6X PCI Express 4.0 x16 Video Card ROG-STRIX-RTX3080-O10G-V2-GAMING (LHR) and Intel Core i9-11900K - Core i9 11th Gen Rocket Lake 8-Core 3.5 GHz LGA 1200 125W Intel UHD Graphics 750 Desk
# $2674
# https://www.newegg.ca/Product/ComboDealDetails?ItemList=Combo.4433971
#
#
#
#
#
#
# ASUS TUF Gaming NVIDIA GeForce RTX 3080 V2 OC Edition Graphics Card (PCIe 4.0 10GB GDDR6X LHR HDMI 2.1 DisplayPort 1.4a Dual Ball Fan Bearings Military-grade Certification GPU Tweak II) and Intel Core i9-11900K - Core i9 11th Gen Rocket Lak
# $2674
# https://www.newegg.ca/Product/ComboDealDetails?ItemList=Combo.4433975
#
#
#
#
#
#
# ASUS ROG STRIX GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 x16 ATX Video Card ROG-STRIX-RTX3080-O10G-WHITE-V2 (LHR) and ASUS PRIME Z590-A LGA 1200 Intel Z590 SATA 6Gb/s ATX Intel Motherboard and Intel Core i9-11900K - Core i9 11th Gen Rock
# $2703
# https://www.newegg.ca/Product/ComboDealDetails?ItemList=Combo.4451914
#
#
#
#
#
#
# ASUS TUF Gaming GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 Video Card TUF-RTX3080TI-O12G-GAMING and ASUS ROG STRIX Z590-A GAMING WIFI LGA 1200 Intel Z590 SATA 6Gb/s ATX Intel Motherboard and Rosewill SMG750 80 Plus Gold Certified 750W
# $2733
# https://www.newegg.ca/Product/ComboDealDetails?ItemList=Combo.4452328
#
#
#
#
#
#
# MSI Ventus GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 x16 ATX Video Card RTX 3080 Ti Ventus 3X 12G OC
# $2849
# https://www.newegg.ca/p/1FT-0009-006C5?Description=3080&cm_re=3080-_-1FT-0009-006C5-_-Product
#
#
#
#
#
#
# EVGA GeForce RTX 3080 12GB GDDR6X PCI Express 4.0 ATX Video Card 12G-P5-4877-KL and Intel Core i9-11900K - Core i9 11th Gen Rocket Lake 8-Core 3.5 GHz LGA 1200 125W Intel UHD Graphics 750 Desktop Processor - BX8070811900K and ASRock Z590 PR
# $2863
# https://www.newegg.ca/Product/ComboDealDetails?ItemList=Combo.4452626
#
#
#
#
#
#
# EVGA GeForce RTX 3080 Ti FTW3 ULTRA GAMING Video Card, 12G-P5-3967-KR, 12GB GDDR6X, iCX3 Technology, ARGB LED, Metal Backplate
# $2883
# https://www.newegg.ca/p/1FT-001K-00DN6?Description=3080&cm_re=3080-_-9SIAVF2HKG6145-_-Product
#
#
#
#
#
#
# MSI Gaming GeForce RTX 3080 12GB GDDR6X PCI Express 4.0 ATX Video Card RTX 3080 GAMING Z TRIO 12G LHR and AMD Ryzen 9 5900X - Ryzen 9 5000 Series Vermeer (Zen 3) 12-Core 3.7 GHz Socket AM4 105W Desktop Processor - 100-100000061WOF and MSI M
# $2893
# https://www.newegg.ca/Product/ComboDealDetails?ItemList=Combo.4456515
#
#
#
#
#
#
# GIGABYTE Gaming GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 x16 ATX Video Card GV-N308TGAMING OC-12GD
# $2899
# https://www.newegg.ca/p/1FT-000A-002A6?Description=3080&cm_re=3080-_-9SIAG9DGGP0141-_-Product
#
#
#
#
#
#
# GAINWARD GeForce RTX 3080 Ti chasing the wind Ti 12GB GDDR6X PCI Express 4.0 Video Card RTX 3080 Ti Gaming X Trio 12G
# $2899
# https://www.newegg.ca/gainward-ga102-225/p/27N-0075-00014?Description=3080&cm_re=3080-_-27N-0075-00014-_-Product
#
#
#
#
#
#
# ABS Gladiator Gaming PC - Intel i7 10700F - GeForce RTX 3080 - 16GB DDR4 3000MHz - 1TB M.2 NVMe SSD
# $2899
# https://www.newegg.ca/abs-ali440/p/N82E16883360024?Description=3080&cm_re=3080-_-83-360-024-_-Product
#
#
#
#
#
#
# MSI Gaming GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 Video Card RTX 3080 Ti Gaming X Trio 12G and AMD Ryzen 7 5800X - Ryzen 7 5000 Series Vermeer (Zen 3) 8-Core 3.8 GHz Socket AM4 105W Desktop Processor - 100-100000063WOF and MSI MPG
# $2923
# https://www.newegg.ca/Product/ComboDealDetails?ItemList=Combo.4358158
#
#
#
#
#
#
# ASUS TUF Gaming GeForce RTX 3080 Ti OC Edition Graphics Card (PCIe 4.0, 12GB GDDR6X, HDMI 2.1, DisplayPort 1.4a, Dual Ball Fan Bearings), TUF-RTX3080TI-O12G-GAMING
# $2930
# https://www.newegg.ca/p/1FT-000Y-00614?Description=3080&cm_re=3080-_-1FT-000Y-00614-_-Product
#
#
#
#
#
#
# MSI Gaming GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 x16 Video Card RTX 3080 Ti Gaming X Trio 12G
# $2957
# https://www.newegg.ca/p/1FT-0009-006C7?Description=3080&cm_re=3080-_-1FT-0009-006C7-_-Product
#
#
#
#
#
#
# GIGABYTE Gaming GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 ATX Video Card GV-N308TGAMING OC-12GD and GIGABYTE X570 AORUS ELITE WIFI AM4 AMD X570 SATA 6Gb/s ATX AMD Motherboard and AMD Ryzen 7 5800X - Ryzen 7 5000 Series Vermeer (Zen 3)
# $2964
# https://www.newegg.ca/Product/ComboDealDetails?ItemList=Combo.4445538
#
#
#
#
#
#
# EVGA GeForce RTX 3080 Ti FTW3 ULTRA GAMING Video Card 12G-P5-3967-KR 12GB GDDR6X iCX3 Technology ARGB LED Metal Backplate and Intel Core i9-11900K - Core i9 11th Gen Rocket Lake 8-Core 3.5 GHz LGA 1200 125W Intel UHD Graphics 750 Desktop Pr
# $3008
# https://www.newegg.ca/Product/ComboDealDetails?ItemList=Combo.4450916
#
#
#
#
#
#
# MSI Ventus GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 ATX Video Card RTX 3080 Ti Ventus 3X 12G OC and Intel Core i7-11700K - Core i7 11th Gen Rocket Lake 8-Core 3.6 GHz LGA 1200 125W Intel UHD Graphics 750 Desktop Processor - BX8070811
# $3018
# https://www.newegg.ca/Product/ComboDealDetails?ItemList=Combo.4452857
#
#
#
#
#
#
# GIGABYTE GeForce RTX 3080 EAGLE 10GB Video Card, GV-N3080EAGLE-10GD
# $3024
# https://www.newegg.ca/p/1FT-000A-002E2?Description=3080&cm_re=3080-_-9SIAVF2G3E7967-_-Product
#
#
#
#
#
#
# GIGABYTE AORUS GeForce RTX 3080 XTREME WATERFORCE WB 10G (rev. 2.0) Graphics Card, WATERFORCE Water Block Cooling System, 10GB 320-bit GDDR6X, GV-N3080AORUSX WB-10GD Rev2.0 Video Card (LHR)
# $3087
# https://www.newegg.ca/gigabyte-geforce-rtx-3080-gv-n3080aorusx-wb-10gd-rev2-0/p/N82E16814932477?Description=3080&cm_re=3080-_-9SIAHEBGGX3099-_-Product
#
#
#
#
#
#
# GAINWARD GeForce RTX 3080 Ti glare OC Edition Gaming Graphics Card (PCIe 4.0, 12GB GDDR6X, HDMI 2.1, 384bit,1695MHz)
# $3099
# https://www.newegg.ca/gainward-ga102-225/p/27N-0075-00016?Description=3080&cm_re=3080-_-27N-0075-00016-_-Product
#
#
#
#
#
#
# ASUS ROG Strix GeForce RTX 3080 Ti OC Edition Gaming Graphics Card (PCIe 4.0, 12GB GDDR6X, HDMI 2.1, DisplayPort 1.4a, Axial-tech Fan Design, 2.9-slot), ROG-STRIX-RTX3080TI-O12G-GAMING
# $3099
# https://www.newegg.ca/p/1FT-000Y-00615?Description=3080&cm_re=3080-_-1FT-000Y-00615-_-Product
#
#
#
#
#
#
# ABS Gladiator Gaming PC - Windows 10 Home - Intel i7 11700F - GeForce RTX 3080 - G.Skill TridentZ RGB 16GB DDR4 3200 MHz - 1TB M.2 NVMe SSD
# $3099
# https://www.newegg.ca/abs-ali597/p/N82E16883360232?Description=3080&cm_re=3080-_-83-360-232-_-Product
#
#
#
#
#
#
# GIGABYTE AORUS GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 ATX Video Card GV-N308TAORUS M-12GD and Intel Core i9-11900K - Core i9 11th Gen Rocket Lake 8-Core 3.5 GHz LGA 1200 125W Intel UHD Graphics 750 Desktop Processor - BX8070811900K
# $3133
# https://www.newegg.ca/Product/ComboDealDetails?ItemList=Combo.4431187
#
#
#
#
#
#
# ASUS TUF Gaming GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 Video Card TUF-RTX3080TI-O12G-GAMING and Intel Core i9-11900K - Core i9 11th Gen Rocket Lake 8-Core 3.5 GHz LGA 1200 125W Intel UHD Graphics 750 Desktop Processor - BX807081190
# $3184
# https://www.newegg.ca/Product/ComboDealDetails?ItemList=Combo.4420236
#
#
#
#
#
#
# GIGABYTE Gaming GeForce RTX 3080 GAMING OC WATERFORCE WB 10GB GDDR6X PCI Express 4.0 x16 ATX Video Card GV-N3080GAMINGOC WB-10GD
# $3189
# https://www.newegg.ca/gigabyte-geforce-rtx-3080-gv-n3080gamingoc-wb-10gd/p/N82E16814932424?Description=3080&cm_re=3080-_-9SIAHEBG0C5575-_-Product
#
#
#
#
#
#
# ASUS ROG Strix NVIDIA GeForce RTX 3080 Ti OC Edition Gaming Graphics Card (PCIe 4.0, 12GB GDDR6X, HDMI 2.1, Axial-tech Fan Design, 2.9-Slot, Super Alloy Power II, ASUS Auto-Extreme Technology)
# $3199
# https://www.newegg.ca/asus-geforce-rtx-3080-ti-rog-strix-rtx3080ti-o12g-gaming/p/N82E16814126508?Description=3080&cm_re=3080-_-14-126-508-_-Product
#
#
#
#
#
#
# ABS Gladiator Gaming PC - Ryzen 7 3700X - GeForce RTX 3080 - G.Skill TridentZ RGB 16GB DDR4 3200MHz - 1TB M.2 NVMe SSD - 240MM RGB AIO
# $3199
# https://www.newegg.ca/abs-ala236/p/N82E16883360100?Description=3080&cm_re=3080-_-83-360-100-_-Product
#
#
#
#
#
#
# ASUS ROG Strix GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 Video Card ROG-STRIX-RTX3080-O10G-GAMING
# $3202
# https://www.newegg.ca/asus-geforce-rtx-3080-rog-strix-rtx3080-o10g-gaming/p/N82E16814126457?Description=3080&cm_re=3080-_-14-126-457-_-Product
#
#
#
#
#
#
# GIGABYTE AORUS GeForce RTX 3080 XTREME WATERFORCE 10GB Video Card, GV-N3080AORUSX W-10GD,NOT LHR
# $3248
# https://www.newegg.ca/p/1FT-000A-002D2?Description=3080&cm_re=3080-_-9SIAVF2G3E9884-_-Product
#
#
#
#
#
#
# ASUS ROG Strix GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 x16 Video Card ROG-STRIX-RTX3080-O10G-V2-GAMING LHR
# $3249
# https://www.newegg.ca/p/1FT-000Y-00669?Description=3080&cm_re=3080-_-9SIAGYBGPP9489-_-Product
#
#
#
#
#
#
# MSI Suprim GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 ATX Video Card RTX 3080 Ti SUPRIM X 12G
# $3268
# https://www.newegg.ca/msi-geforce-rtx-3080-ti-suprim-x-12g/p/N82E16814137660?Description=3080&cm_re=3080-_-14-137-660-_-Product
#
#
#
#
#
#
# MSI Gaming GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 x16 Video Card RTX 3080 Ti Gaming Trio 12G
# $3292
# https://www.newegg.ca/p/1FT-0009-006G8?Description=3080&cm_re=3080-_-9SIAVF2G3E8214-_-Product
#
#
#
#
#
#
# ABS Gladiator Gaming PC - Windows 10 Home - Intel i7 11700KF - GeForce RTX 3080 - G.Skill TridentZ RGB 16GB DDR4 3200MHz - 1TB Intel M.2 NVMe SSD
# $3299
# https://www.newegg.ca/abs-ali602/p/N82E16883360267?Description=3080&cm_re=3080-_-83-360-267-_-Product
#
#
#
#
#
#
# ABS Gladiator Gaming PC - Windows 10 Home - Intel i7 10700KF - GeForce RTX 3080 - G.Skill TridentZ RGB 16GB DDR4 3200MHz - 1TB Intel 670P M.2 NVMe SSD - 240MM RGB AIO Liquid Cooling
# $3299
# https://www.newegg.ca/abs-ali555/p/N82E16883360185?Description=3080&cm_re=3080-_-83-360-185-_-Product
#
#
#
#
#
#
# MSI Ventus GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 Video Card RTX 3080 VENTUS 3X 10G OC
# $3307
# https://www.newegg.ca/p/1FT-0009-006D8?Description=3080&cm_re=3080-_-9SIAVF2G3E7961-_-Product
#
#
#
#
#
#
# ASUS TUF Gaming GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 Video Card TUF-RTX3080TI-12G-GAMING and ASUS ROG Crosshair VIII Dark Hero AM4 AMD X570S SATA 6Gb/s ATX AMD Motherboard
# $3328
# https://www.newegg.ca/Product/ComboDealDetails?ItemList=Combo.4431199
#
#
#
#
#
#
# MSI Ventus GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 ATX Video Card RTX 3080 Ti Ventus 3X 12G OC and AMD Ryzen 9 5950X - Ryzen 9 5000 Series Vermeer (Zen 3) 16-Core 3.4 GHz Socket AM4 105W Desktop Processor - 100-100000059WOF and MSI
# $3333
# https://www.newegg.ca/Product/ComboDealDetails?ItemList=Combo.4441697
#
#
#
#
#
#
# ABS Gladiator Gaming PC - Intel i9 10850K - ASUS TUF GeForce RTX 3080 OC 10GB - G.Skill TridentZ RGB 32GB DDR4 3200MHz - 1TB Intel M.2 NVMe SSD - RGB AIO 240MM
# $3349
# https://www.newegg.ca/abs-ali460/p/N82E16883360045?Description=3080&cm_re=3080-_-83-360-045-_-Product
#
#
#
#
#
#
# ABS Gladiator Gaming PC - Windows 11 Pro - Intel i7 11700KF - GeForce RTX 3080 - G.Skill TridentZ RGB 16GB DDR4 3200MHz - 1TB PCIe Gen4 M.2 NVMe SSD
# $3399
# https://www.newegg.ca/abs-ali582/p/N82E16883360217?Description=3080&cm_re=3080-_-83-360-217-_-Product
#
#
#
#
#
#
# ASUS Gaming Desktop ROG Strix G35DX-DHR780 Ryzen 7 5000 Series 5800X (3.80GHz) 16GB DDR4 1 TB PCIe SSD NVIDIA GeForce RTX 3080 Windows 10 Home 64-bit
# $3399
# https://www.newegg.ca/asus-g35dx-dhr780-rog-strix/p/N82E16883221694R?Description=3080&cm_re=3080-_-83-221-694R-_-Product
#
#
#
#
#
#
# GIGABYTE AORUS GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 ATX Video Card GV-N308TAORUS X-12GD
# $3460
# https://www.newegg.ca/gigabyte-geforce-rtx-3080-ti-xtreme-12g/p/N82E16814932440?Description=3080&cm_re=3080-_-9SIAGYBEWR1896-_-Product
#
#
#
#
#
#
# ZOTAC GAMING GeForce RTX 3080 AMP Holo 10GB GDDR6X 320-bit 19 Gbps PCIE 4.0 Gaming Graphics Card, HoloBlack, IceStorm 2.0 Advanced Cooling, SPECTRA 2.0 RGB Lighting, ZT-A30800F-10P
# $3479
# https://www.newegg.ca/zotac-geforce-rtx-3080-zt-a3080f-10p/p/N82E16814500513?Description=3080&cm_re=3080-_-9SIB3H2G9W0825-_-Product
#
#
#
#
#
#
# ASUS ROG Strix NVIDIA GeForce RTX 3080 Ti OC Edition Gaming Graphics Card (PCIe 4.0 12GB GDDR6X HDMI 2.1 Axial-tech Fan Design 2.9-Slot Super Alloy Power II ASUS Auto-Extreme Technology) and Intel Core i9-11900K - Core i9 11th Gen Rocket La
# $3484
# https://www.newegg.ca/Product/ComboDealDetails?ItemList=Combo.4420234
#
#
#
#
#
#
# ABS Gladiator Gaming PC - Intel i9-10850K - GeForce RTX 3080 - G.Skill TridentZ RGB 32GB DDR4 3200MHz - 1TB M.2 NVMe SSD
# $3499
# https://www.newegg.ca/abs-ali441/p/N82E16883360025?Description=3080&cm_re=3080-_-83-360-025-_-Product
#
#
#
#
#
#
# GAINWARD GeForce RTX 3080 Ti Star pole Blue Jazz OCEdition Gaming Graphics Card (PCIe 4.0, 12GB GDDR6X, HDMI 2.1, 384bit,1695MHz)
# $3599
# https://www.newegg.ca/gainward-bule-jazz/p/27N-0075-00015?Description=3080&cm_re=3080-_-27N-0075-00015-_-Product
#
#
#
#
#
#
# ABS Gladiator Gaming PC - Windows 10 Home - Intel i7 11700KF - GeForce RTX 3080 - G.Skill TridentZ RGB 16GB DDR4 3200MHz - 1TB PCIe Gen4 M.2 NVMe SSD
# $3599
# https://www.newegg.ca/abs-ali577/p/N82E16883360212?Description=3080&cm_re=3080-_-83-360-212-_-Product
#
#
#
#
#
#
# ASUS ROG Strix GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 x16 Video Card ROG-STRIX-RTX3080-O10G-GAMING,Not LHR. Do not lock hashrate
# $3600
# https://www.newegg.ca/p/1FT-000Y-00625?Description=3080&cm_re=3080-_-9SIB2K2GPN8674-_-Product
#
#
#
#
#
#
# GIGABYTE AORUS GeForce RTX 3080 XTREME WATERFORCE 10GB Video Card, GV-N3080AORUSX W-10GD
# $3629
# https://www.newegg.ca/gigabyte-geforce-rtx-3080-gv-n3080aorusx-w-10gd/p/N82E16814932372?Description=3080&cm_re=3080-_-9SIAHEBFRN0902-_-Product
#
#
#
#
#
#
# ASUS TUF Gaming NVIDIA GeForce RTX 3080 Ti Graphics Card (PCIe 4.0, 12GB GDDR6X, HDMI 2.1, DisplayPort 1.4a, Dual Ball Fan Bearings, Military-grade Certification), TUF-RTX3080TI-12G-GAMING
# $3629
# https://www.newegg.ca/p/1FT-000Y-005V9?Description=3080&cm_re=3080-_-1FT-000Y-005V9-_-Product
#
#
#
#
#
#
# ABS Legend Gaming PC - Windows 10 Home - Intel i7 10700KF - EVGA GeForce RTX 3080 Ti XC3 Ultra Gaming - G.Skill TridentZ RGB 16GB DDR4 3200MHz - 1TB Intel 670P M.2 NVMe SSD - 240MM RGB AIO
# $3799
# https://www.newegg.ca/abs-ali552/p/N82E16883360182?Description=3080&cm_re=3080-_-83-360-182-_-Product
#
#
#
#
#
#
# GIGABYTE AORUS GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 ATX Video Card GV-N308TAORUSX WB-12GD
# $3808
# https://www.newegg.ca/gigabyte-geforce-rtx-3080-ti-gv-n308taorusx-wb-12gd/p/N82E16814932463?Description=3080&cm_re=3080-_-9SIAHEBGDJ3297-_-Product
#
#
#
#
#
#
# ABS Legend Gaming PC - Windows 10 Home - Intel i7 10700KF - GeForce RTX 3080 Ti 12GB - G.Skill TridentZ RGB 16GB DDR4 3200MHz - 1TB Intel 670P M.2 NVMe SSD - 240MM RGB AIO Liquid Cooling
# $3849
# https://www.newegg.ca/abs-ali561/p/N82E16883360191?Description=3080&cm_re=3080-_-83-360-191-_-Product
#
#
#
#
#
#
# CLX SET VR-Ready Gaming Desktop - Liquid Cooled AMD Ryzen 7 5800X 3.8Ghz 8-Core Processor, 16GB DDR4 Memory, GeForce RTX 3080 10GB GDDR6X Graphics, 240GB SSD, 2TB HDD, WiFi, Windows 10 Home 64-bit
# $3887
# https://www.newegg.ca/clx-tgmsetrtm0b03bm/p/3D5-000B-001T6?Description=3080&cm_re=3080-_-9SIACY7F5G3918-_-Product
#
#
#
#
#
#
# CLX SET VR-Ready Gaming Desktop - Liquid Cooled Intel Core i9 9900KF 3.6Ghz 8-Core Processor, 16GB DDR4 Memory, GeForce RTX 3080 10GB GDDR6X Graphics, 480GB SSD, 2TB HDD, WiFi, Windows 10 Home 64-bit
# $3896
# https://www.newegg.ca/clx-tgmsetrth0a25bm/p/3D5-000B-001M5?Description=3080&cm_re=3080-_-9SIACY7F6J8623-_-Product
#
#
#
#
#
#
# ABS Gladiator Gaming PC - Ryzen 9 5900X - EVGA GeForce RTX 3080 FTW3 Ultra Gaming - CORSAIR Vengeance RGB 32GB DDR4 3600MHz - 1TB Intel M.2 NVMe SSD - EVGA CLC 240MM AIO
# $3899
# https://www.newegg.ca/abs-ala238/p/N82E16883360102?Description=3080&cm_re=3080-_-83-360-102-_-Product
#
#
#
#
#
#
# CLX SET Gaming Desktop - Intel Core i7 10700 Processor, 16GB DDR4 Memory, NVIDIA GeForce RTX 3080 Graphics, 240 GB SSD, 2 TB HDD, WiFi, Windows 10 Home 64-bit
# $3934
# https://www.newegg.ca/clx-tgmsetrth0920bm/p/3D5-000B-00176?Description=3080&cm_re=3080-_-9SIACY7FH99031-_-Product
#
#
#
#
#
#
# CLX SET Gaming Desktop - Intel Core i7 10700KF Processor, 16GB DDR4 Memory, NVIDIA GeForce RTX 3080 Graphics, 240 GB SSD, 2 TB HDD, WiFi, Windows 10 Home 64-bit
# $3987
# https://www.newegg.ca/clx-tgmsetrth0921bm/p/3D5-000B-00180?Description=3080&cm_re=3080-_-9SIACY7F5G3920-_-Product
#
#
#
#
#
#
# MSI Gaming Desktop MEG Trident X 11TE-1683CA Intel Core i7 11th Gen 11700K (3.60GHz) 32GB DDR4 1 TB PCIe SSD NVIDIA GeForce RTX 3080 Windows 10 Home 64-bit
# $3988
# https://www.newegg.ca/msi-meg-trident-x-11te-1683ca/p/N82E16883152794?Description=3080&cm_re=3080-_-9SIADGEGF28001-_-Product
#
#
#
#
#
#
# ABS Gladiator Gaming PC - Windows 10 Pro - Ryzen 7 5800X - GeForce RTX 3080 - G.Skill TridentZ RGB 32GB DDR4 3200MHz - 1TB Gen4 M.2 SSD - Corsair 280MM RGB AIO
# $3999
# https://www.newegg.ca/abs-ala268/p/N82E16883360202?Description=3080&cm_re=3080-_-83-360-202-_-Product
#
#
#
#
#
#
# CLX SET Gaming Desktop - AMD Ryzen 7 3700X Processor, 16GB DDR4 Memory, NVIDIA GeForce RTX 3080 Graphics, 240 GB SSD, 2 TB HDD, WiFi, Windows 10 Home 64-bit
# $4034
# https://www.newegg.ca/clx-tgmsetrth0900bm/p/3D5-000B-00140?Description=3080&cm_re=3080-_-9SIACY7FH99019-_-Product
#
#
#
#
#
#
# CLX SET VR-Ready Gaming Desktop - Liquid Cooled AMD Ryzen 9 5900X 3.7Ghz 12-Core Processor, 16GB DDR4 Memory, GeForce RTX 3080 10GB GDDR6X Graphics, 240GB SSD, 2TB HDD, WiFi, Windows 10 Home 64-bit
# $4048
# https://www.newegg.ca/clx-tgmsetrth0b04bm/p/3D5-000B-001N2?Description=3080&cm_re=3080-_-9SIACY7F5G3921-_-Product
#
#
#
#
#
#
# ASUS ROG Strix GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 x16 Video Card ROG-STRIX-RTX3080-O10G-GUNDAM,WHITE GPU,WHITE Graphics Card
# $4048
# https://www.newegg.ca/p/1FT-000Y-00611?Description=3080&cm_re=3080-_-1FT-000Y-00611-_-Product
#
#
#
#
#
#
# GIGABYTE AORUS GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 ATX Video Card GV-N308TAORUSX W-12GD
# $4073
# https://www.newegg.ca/gigabyte-geforce-rtx-3080-ti-gv-n308taorusx-w-12gd/p/N82E16814932462?Description=3080&cm_re=3080-_-14-932-462-_-Product
#
#
#
#
#
#
# ASUS ROG STRIX NVIDIA GeForce RTX 3080 GUNDAM EDITION Graphics Card (Limited Edition, PCIe 4.0, 10GB GDDR6X, HDMI 2.1, DisplayPort 1.4a, Axial-tech Fan Design, 2.9-slot, Super Alloy Power II)
# $4099
# https://www.newegg.ca/asus-rog-strix-nvidia-geforce-rtx-3080-gundam-edition/p/N82E16814126506?Description=3080&cm_re=3080-_-14-126-506-_-Product
#
#
#
#
#
#
# CLX SET Gaming Desktop - Intel Core i7 10700 Processor, 32GB DDR4 Memory, NVIDIA GeForce RTX 3080 Graphics, 480 GB SSD, 3 TB HDD, WiFi, Windows 10 Home 64-bit
# $4128
# https://www.newegg.ca/clx-tgmsetrth0923bm/p/3D5-000B-00144?Description=3080&cm_re=3080-_-9SIACY7FH99039-_-Product
#
#
#
#
#
#
# CLX SET Gaming Desktop - Intel Core i9 10850K Processor, 16GB DDR4 Memory, NVIDIA GeForce RTX 3080 Graphics, 480 GB SSD, 2 TB HDD, WiFi, Windows 10 Home 64-bit
# $4133
# https://www.newegg.ca/clx-tgmsetrth0927bm/p/3D5-000B-00196?Description=3080&cm_re=3080-_-9SIACY7F5G3931-_-Product
#
#
#
#
#
#
# CLX SET Gaming Desktop - AMD Ryzen 7 3800X Processor, 16GB DDR4 Memory, NVIDIA GeForce RTX 3080 Graphics, 240 GB SSD, 2 TB HDD, WiFi, Windows 10 Home 64-bit
# $4141
# https://www.newegg.ca/clx-tgmsetrth0901bm/p/3D5-000B-00147?Description=3080&cm_re=3080-_-9SIACY7F5G3889-_-Product
#
#
#
#
#
#
# MSI Gaming Desktop Aegis RS 11TF-223US Intel Core i7 11th Gen 11700K (3.60 GHz) 32 GB DDR4 2 TB HDD 2 TB PCIe Gen3 SSD NVIDIA GeForce RTX 3080 Ti Windows 10 Home 64-bit
# $4149
# https://www.newegg.ca/msi-aegis-rs-11tf-223us/p/N82E16883152859?Description=3080&cm_re=3080-_-83-152-859-_-Product
#
#
#
#
#
#
# CLX SET VR-Ready Gaming Desktop - Liquid Cooled Intel Core i9 10900KF 3.7Ghz 10-Core Processor, 16GB DDR4 Memory, GeForce RTX 3080 10GB GDDR6X Graphics, 480GB SSD, 2TB HDD, WiFi, Win 10 Home 64-bit
# $4155
# https://www.newegg.ca/clx-tgmsetrth0a26bm/p/3D5-000B-001M3?Description=3080&cm_re=3080-_-9SIACY7F6J8625-_-Product
#
#
#
#
#
#
# CLX SET Gaming Desktop - AMD Ryzen 9 3900X Processor, 16GB DDR4 Memory, NVIDIA GeForce RTX 3080 Graphics, 240 GB SSD, 2 TB HDD, WiFi, Windows 10 Home 64-bit
# $4162
# https://www.newegg.ca/clx-tgmsetrth0902bm/p/3D5-000B-00150?Description=3080&cm_re=3080-_-9SIACY7F5G3898-_-Product
#
#
#
#
#
#
# CLX SET Gaming Desktop - AMD Ryzen 7 3700X Processor, 32GB DDR4 Memory, NVIDIA GeForce RTX 3080 Graphics, 480 GB SSD, 3 TB HDD, WiFi, Windows 10 Home 64-bit
# $4232
# https://www.newegg.ca/clx-tgmsetrth0903bm/p/3D5-000B-00155?Description=3080&cm_re=3080-_-9SIACY7FH99024-_-Product
#
#
#
#
#
#
# CLX SET VR-Ready Gaming Desktop - Liquid Cooled Intel Core i9 9900KF 3.6Ghz 8-Core Processor, 32GB DDR4 Memory, GeForce RTX 3080 10GB GDDR6X Graphics, 960GB SSD, 4TB HDD, WiFi, Windows 10 Home 64-bit
# $4249
# https://www.newegg.ca/clx-tgmsetrth0a18br/p/3D5-000B-001J8?Description=3080&cm_re=3080-_-9SIACY7F6J8622-_-Product
#
#
#
#
#
#
# ABS Legend Gaming PC - Windows 10 Home - Intel i9 11900KF - GeForce RTX 3080 Ti - G.Skill TridentZ RGB 16GB DDR4 3200 MHz - 1TB Intel M.2 NVMe SSD
# $4299
# https://www.newegg.ca/abs-ali593/p/N82E16883360228?Description=3080&cm_re=3080-_-83-360-228-_-Product
#
#
#
#
#
#
# CLX SET Gaming Desktop - AMD Ryzen 7 3800X Processor, 32GB DDR4 Memory, NVIDIA GeForce RTX 3080 Graphics, 480 GB SSD, 3 TB HDD, WiFi, Windows 10 Home 64-bit
# $4338
# https://www.newegg.ca/clx-tgmsetrth0904bm/p/3D5-000B-00158?Description=3080&cm_re=3080-_-9SIACY7F5G3903-_-Product
#
#
#
#
#
#
# CLX SET VR-Ready Gaming Desktop - Liquid Cooled AMD Ryzen 7 5800X 3.8Ghz 8-Core Processor, 32GB DDR4 Memory, GeForce RTX 3080 10GB GDDR6X Graphics, 480GB SSD, 3TB HDD, WiFi, Windows 10 Home 64-bit
# $4338
# https://www.newegg.ca/clx-tgmsetrtm0b09bm/p/3D5-000B-001P9?Description=3080&cm_re=3080-_-9SIACY7F5G3933-_-Product
#
#
#
#
#
#
# CLX SET Gaming Desktop - Intel Core i7 10700KF Processor, 32GB DDR4 Memory, NVIDIA GeForce RTX 3080 Graphics, 960 GB SSD, 4 TB HDD, WiFi, Windows 10 Home 64-bit
# $4342
# https://www.newegg.ca/clx-tgmsetrth0925br/p/3D5-000B-00152?Description=3080&cm_re=3080-_-9SIACY7F5G3927-_-Product
#
#
#
#
#
#
# CLX SET Gaming Desktop - AMD Ryzen 9 3900X Processor, 32GB DDR4 Memory, NVIDIA GeForce RTX 3080 Graphics, 480 GB SSD, 3 TB HDD, WiFi, Windows 10 Home 64-bit
# $4356
# https://www.newegg.ca/clx-tgmsetrth0905bm/p/3D5-000B-00162?Description=3080&cm_re=3080-_-9SIACY7F5G3907-_-Product
#
#
#
#
#
#
# CLX SET VR-Ready Gaming Desktop - Liquid Cooled AMD Ryzen 7 5800X 3.8Ghz 8-Core Processor, 32GB DDR4 Memory, GeForce RTX 3080 10GB GDDR6X Graphics, 960GB SSD, 4TB HDD, WiFi, Windows 10 Home 64-bit
# $4386
# https://www.newegg.ca/clx-tgmsetrtm0b16br/p/3D5-000B-001T7?Description=3080&cm_re=3080-_-9SIACY7F5G3939-_-Product
#
#
#
#
#
#
# CLX SET Gaming Desktop - AMD Ryzen 7 3800X Processor, 32GB DDR4 Memory, NVIDIA GeForce RTX 3080 Graphics, 960 GB SSD, 4 TB HDD, WiFi, Windows 10 Home 64-bit
# $4417
# https://www.newegg.ca/clx-tgmsetrth0907br/p/3D5-000B-00170?Description=3080&cm_re=3080-_-9SIACY7F5G3915-_-Product
#
#
#
#
#
#
# CLX SET Gaming Desktop - AMD Ryzen 7 3800X 3.9GHz 8-Core Processor, 16GB DDR4 Memory, GeForce RTX 3080 Ti 12GB GDDR6X Graphics, 500GB SSD, 3TB HDD, WiFi, Windows 10 Home 64-bit
# $4459
# https://www.newegg.ca/clx-tgmsetrtm1666bm/p/3D5-000B-002B3?Description=3080&cm_re=3080-_-9SIACY7FAT1257-_-Product
#
#
#
#
#
#
# CLX SET Gaming Desktop - Intel Core i9 10850K Processor, 32GB DDR4 Memory, NVIDIA GeForce RTX 3080 Graphics, 960 GB SSD, 4 TB HDD, WiFi, Windows 10 Home 64-bit
# $4486
# https://www.newegg.ca/clx-tgmsetrth0926br/p/3D5-000B-00194?Description=3080&cm_re=3080-_-9SIACY7F5G3929-_-Product
#
#
#
#
#
#
# CLX SET VR-Ready Gaming Desktop - Liquid Cooled AMD Ryzen 9 5900X 3.7GHz 12-Core Processor, 32GB DDR4 Memory, GeForce RTX 3080 10GB GDDR6X Graphics, 480GB SSD, 3TB HDD, WiFi, Windows 10 Home 64-bit
# $4499
# https://www.newegg.ca/clx-tgmsetrth0b10bm/p/3D5-000B-001R3?Description=3080&cm_re=3080-_-9SIACY7F5G3936-_-Product
#
#
#
#
#
#
# CLX SET Gaming Desktop - AMD Ryzen 9 3900X 3.8GHz 12-Core Processor, 16GB DDR4 Memory, GeForce RTX 3080 Ti 12GB GDDR6X Graphics, 500GB SSD, 3TB HDD, WiFi, Windows 10 Home 64-bit
# $4550
# https://www.newegg.ca/clx-tgmsetrtm1667bm/p/3D5-000B-002B8?Description=3080&cm_re=3080-_-9SIACY7FAT1248-_-Product
#
#
#
#
#
#
# CLX SET VR-Ready Gaming Desktop - Liquid Cooled AMD Ryzen 9 5900X 3.7Ghz 12-Core Processor, 32GB DDR4 Memory, GeForce RTX 3080 10GB GDDR6X Graphics, 960GB SSD, 4TB HDD, WiFi, Windows 10 Home 64-bit
# $4563
# https://www.newegg.ca/clx-tgmsetrth0b17br/p/3D5-000B-001T8?Description=3080&cm_re=3080-_-9SIACY7F5G3932-_-Product
#
#
#
#
#
#
# CLX SET Gaming Desktop - AMD Ryzen 9 3900X Processor, 32GB DDR4 Memory, NVIDIA GeForce RTX 3080 Graphics, 960 GB SSD, 4 TB HDD, WiFi, Windows 10 Home 64-bit
# $4568
# https://www.newegg.ca/clx-tgmsetrth0908br/p/3D5-000B-00173?Description=3080&cm_re=3080-_-9SIACY7F5G3919-_-Product
#
#
#
#
#
#
# CLX SET VR-Ready Gaming Desktop - Liquid Cooled AMD Ryzen 9 5950X 3.4Ghz 16-Core Processor, 16GB DDR4 Memory, GeForce RTX 3080 10GB GDDR6X Graphics, 240GB SSD, 2TB HDD, WiFi, Windows 10 Home 64-bit
# $4592
# https://www.newegg.ca/clx-tgmsetrth0b05bm/p/3D5-000B-001N3?Description=3080&cm_re=3080-_-9SIACY7F5G3925-_-Product
#
#
#
#
#
#
# CLX SET Gaming Desktop - Liquid Cooled Intel Core i7 10700KF 3.8GHz 8-Core Processor, 16GB DDR4 Memory, GeForce RTX 3080 Ti 12GB GDDR6X Graphics, 500GB NVMe M.2 SSD, 3TB HDD, WiFi, Win 10 Home 64-bit
# $4623
# https://www.newegg.ca/clx-tgmsetrth1662bm/p/3D5-000B-002F3?Description=3080&cm_re=3080-_-9SIACY7FFU7572-_-Product
#
#
#
#
#
#
# ABS Legend Gaming PC - Windows 10 Home - Intel i7 11700K - ASUS TUF GeForce RTX 3080 Ti OC Edition - G.Skill TridentZ RGB 32GB DDR4 3200MHz - 1TB AORUS GEN4 M.2 NVMe SSD - EVGA CLC 360MM RGB AIO
# $4699
# https://www.newegg.ca/abs-ali562/p/N82E16883360192?Description=3080&cm_re=3080-_-83-360-192-_-Product
#
#
#
#
#
#
# SFT War Scythe Gaming Computer i5 11th Gen, 16G RAM, RTX 3080, 1T SSD, WiFi Ready
# $4699
# https://www.newegg.ca/sft-war-scythe/p/3D5-001S-00012?Description=3080&cm_re=3080-_-9SIASUAEVB4658-_-Product
#
#
#
#
#
#
# CLX SET Gaming Desktop - Intel Core i7 10700KF Processor, 64GB DDR4 Memory, NVIDIA GeForce RTX 3080 Graphics, 1 TB SSD, 6 TB HDD, WiFi, Windows 10 Home 64-bit
# $4742
# https://www.newegg.ca/clx-tgmsetrth0928bm/p/3D5-000B-00192?Description=3080&cm_re=3080-_-9SIACY7F5G3888-_-Product
#
#
#
#
#
#
# SFT Jitte Gaming Computer, Intel i7-10700, 16G RAM, RTX 3080, 1T NVME SSD, Win 10 Home, WiFi Ready
# $4749
# https://www.newegg.ca/p/3D5-001S-00019?Description=3080&cm_re=3080-_-9SIASUAGJ69484-_-Product
#
#
#
#
#
#
# CLX SET Gaming Desktop - Liquid Cooled Intel Core i7 10700KF 3.8GHz 8-Core Processor, 32GB DDR4 Memory, GeForce RTX 3080 Ti 12GB GDDR6X Graphics, 500GB SSD, 4TB HDD, WiFi, Windows 10 Home 64-bit
# $4758
# https://www.newegg.ca/clx-tgmsetrth1672bm/p/3D5-000B-002C9?Description=3080&cm_re=3080-_-9SIACY7FAT1256-_-Product
#
#
#
#
#
#
# CLX SET Gaming Desktop - Liquid Cooled Intel Core i7 11700KF 3.6GHz 8-Core Processor, 16GB DDR4 Memory, GeForce RTX 3080 Ti 12GB GDDR6X Graphics, 500GB NVMe M.2 SSD, 3TB HDD, WiFi, Win 10 Home 64-bit
# $4763
# https://www.newegg.ca/clx-tgmsetrth1663bm/p/3D5-000B-002F8?Description=3080&cm_re=3080-_-9SIACY7FFU7601-_-Product
#
#
#
#
#
#
# CLX SET Gaming Desktop - Liquid Cooled AMD Ryzen 9 5900X 3.7GHz 12-Core Processor, 16GB DDR4 Memory, GeForce RTX 3080 Ti 12GB GDDR6X Graphics, 500GB NVMe M.2 SSD, 3TB HDD, WiFi, Win 10 Home 64-bit
# $4797
# https://www.newegg.ca/clx-tgmsetrth1669bm/p/3D5-000B-002H3?Description=3080&cm_re=3080-_-9SIACY7FFU7591-_-Product
#
#
#
#
#
#
# CLX SET VR-Ready Gaming Desktop - Liquid Cooled AMD Ryzen 7 5800X 3.8Ghz 8-Core Processor, 64GB DDR4 Memory, GeForce RTX 3080 10GB GDDR6X Graphics, 1TB SSD, 6TB HDD, WiFi, Windows 10 Home 64-bit
# $4812
# https://www.newegg.ca/clx-tgmsetrtm0b24bm/p/3D5-000B-001T9?Description=3080&cm_re=3080-_-9SIACY7F5G3935-_-Product
#
#
#
#
#
#
# CLX SET Gaming Desktop - AMD Ryzen 7 3800X Processor, 64GB DDR4 Memory, NVIDIA GeForce RTX 3080 Graphics, 1 TB SSD, 6 TB HDD, WiFi, Windows 10 Home 64-bit
# $4816
# https://www.newegg.ca/clx-tgmsetrth0910bm/p/3D5-000B-00183?Description=3080&cm_re=3080-_-9SIACY7F5G3926-_-Product
#
#
#
#
#
#
# CLX SET Gaming Desktop - Liquid Cooled Intel Core i9 10850K 3.6GHz 10-Core Processor, 16GB DDR4 Memory, GeForce RTX 3080 Ti 12GB GDDR6X Graphics, 500GB NVMe M.2 SSD, 3TB HDD, WiFi, Win 10 Home 64-bit
# $4827
# https://www.newegg.ca/clx-tgmsetrth1664bm/p/3D5-000B-002G1?Description=3080&cm_re=3080-_-9SIACY7FFU7598-_-Product
#
#
#
#
#
#
# CLX SET VR-Ready Gaming Desktop - Liquid Cooled AMD Ryzen 9 5950X 3.4Ghz 16-Core Processor, 32GB DDR4 Memory, GeForce RTX 3080 10GB GDDR6X Graphics, 480GB SSD, 3TB HDD, WiFi, Windows 10 Home 64-bit
# $4856
# https://www.newegg.ca/clx-tgmsetrth0b11bm/p/3D5-000B-001R7?Description=3080&cm_re=3080-_-9SIACY7F5G3934-_-Product
#
#
#
#
#
#
# CLX SET Gaming Desktop - Intel Core i9 10850K Processor, 64GB DDR4 Memory, NVIDIA GeForce RTX 3080 Graphics, 1 TB SSD, 6 TB HDD, WiFi, Windows 10 Home 64-bit
# $4886
# https://www.newegg.ca/clx-tgmsetrth0929bm/p/3D5-000B-00195?Description=3080&cm_re=3080-_-9SIACY7F5G3897-_-Product
#
#
#
#
#
#
# CLX SET Gaming Desktop - Liquid Cooled Intel Core i7 11700KF 3.6GHz 8-Core Processor, 32GB DDR4 Memory, GeForce RTX 3080 Ti 12GB GDDR6X Graphics, 500GB SSD, 4TB HDD, WiFi, Windows 10 Home 64-bit
# $4894
# https://www.newegg.ca/clx-tgmsetrth1673bm/p/3D5-000B-002D0?Description=3080&cm_re=3080-_-9SIACY7FAT1254-_-Product
#
#
#
#
#
#
# CLX SET - Liquid Cooled Intel Core i9 10900KF 3.7Ghz 10-Core Processor, 64GB DDR4 Memory, GeForce RTX 3080 10GB GDDR6X Graphics, 1TB SSD, 6TB HDD, WiFi, Win 10 Home 64-bit
# $4917
# https://www.newegg.ca/clx-tgmsetrth0a29bm/p/3D5-000B-001M8?Description=3080&cm_re=3080-_-9SIACY7F6J8624-_-Product
#
#
#
#
#
#
# CLX SET Gaming Desktop - Liquid Cooled AMD Ryzen 7 5800X 3.8GHz 8-Core Processor, 32GB DDR4 Memory, GeForce RTX 3080 Ti 12GB GDDR6X Graphics, 500GB SSD, 4TB HDD, WiFi, Windows 10 Home 64-bit
# $4932
# https://www.newegg.ca/clx-tgmsetrth1670bm/p/3D5-000B-002C1?Description=3080&cm_re=3080-_-9SIACY7FAT1250-_-Product
#
#
#
#
#
#
# CLX SET Gaming Desktop - Liquid Cooled Intel Core i9 10850K 3.6GHz 10-Core Processor, 32GB DDR4 Memory, GeForce RTX 3080 Ti 12GB GDDR6X Graphics, 500GB SSD, 4TB HDD, WiFi, Windows 10 Home 64-bit
# $4958
# https://www.newegg.ca/clx-tgmsetrth1658bm/p/3D5-000B-002A5?Description=3080&cm_re=3080-_-9SIACY7FAT1234-_-Product
#
#
#
#
#
#
# CLX SET Gaming Desktop - AMD Ryzen 9 3900X Processor, 64GB DDR4 Memory, NVIDIA GeForce RTX 3080 Graphics, 1 TB SSD, 6 TB HDD, WiFi, Windows 10 Home 64-bit
# $4974
# https://www.newegg.ca/clx-tgmsetrth0911bm/p/3D5-000B-00141?Description=3080&cm_re=3080-_-9SIACY7F5G3928-_-Product
#
#
#
#
#
#
# CLX SET VR-Ready Gaming Desktop - Liquid Cooled AMD Ryzen 9 5900X 3.7Ghz 12-Core Processor, 64GB DDR4 Memory, GeForce RTX 3080 10GB GDDR6X Graphics, 1TB SSD, 6TB HDD, WiFi, Windows 10 Home 64-bit
# $4985
# https://www.newegg.ca/clx-tgmsetrth0b25bm/p/3D5-000B-001U4?Description=3080&cm_re=3080-_-9SIACY7F5G3937-_-Product
#
#
#
#
#
#
# ABS Gladiator Gaming PC - Windows 10 Home - Intel i9 12900KF - Asus Strix GeForce RTX 3080 - Corsair Vengeance RGB Pro 32GB (2x16GB) DDR4 3200MHz - 2TB M.2 NVMe SSD
# $4999
# https://www.newegg.ca/abs-ali591/p/N82E16883360226?Description=3080&cm_re=3080-_-83-360-226-_-Product
#
#
#
#
#
#
# CyberpowerPC Gaming Desktop Gamer Supreme SLC10780CPG Intel Core i9 11th Gen 11900KF (3.50 GHz) 32 GB DDR4 2 TB HDD 1 TB PCIe SSD NVIDIA GeForce RTX 3080 Ti Windows 10 Home 64-bit
# $5049
# https://www.newegg.ca/cyberpowerpc-slc10780cpg-gamer-supreme/p/N82E16883230652?Description=3080&cm_re=3080-_-83-230-652-_-Product
#
#
#
#
#
#
# CLX SET Gaming Desktop - Intel Core i9 10900X Processor, 32GB DDR4 Memory, NVIDIA GeForce RTX 3080 Graphics, 480 GB SSD, 3 TB HDD, WiFi, Windows 10 Home 64-bit
# $5060
# https://www.newegg.ca/clx-tgmsetrth0913br/p/3D5-000B-00149?Description=3080&cm_re=3080-_-9SIACY7F5G3890-_-Product
#
#
#
#
#
#
# CLX SET Gaming Desktop - Liquid Cooled Intel Core i9 11900KF 3.5GHz 8-Core Processor, 16GB DDR4 Memory, GeForce RTX 3080 Ti 12GB GDDR6X Graphics, 500GB NVMe M.2 SSD, 3TB HDD, WiFi, Win 10 Home 64-bit
# $5067
# https://www.newegg.ca/clx-tgmsetrth1665bm/p/3D5-000B-002G5?Description=3080&cm_re=3080-_-9SIACY7FFU7602-_-Product
#
#
#
#
#
#
# CLX SET Gaming Desktop - AMD Ryzen 9 3950X Processor, 32GB DDR4 Memory, NVIDIA GeForce RTX 3080 Graphics, 960 GB SSD, 4 TB HDD, WiFi, Windows 10 Home 64-bit
# $5073
# https://www.newegg.ca/clx-tgmsetrth0909wr/p/3D5-000B-00177?Description=3080&cm_re=3080-_-9SIACY7F5G3923-_-Product
#
#
#
#
#
#
# CLX SET VR-Ready Gaming Desktop - Liquid Cooled AMD Ryzen 9 5950X 3.4Ghz 16-Core Processor, 32GB DDR4 Memory, GeForce RTX 3080 10GB GDDR6X Graphics, 960GB SSD, 4TB HDD, WiFi, Windows 10 Home 64-bit
# $5101
# https://www.newegg.ca/clx-tgmsetrth0b18br/p/3D5-000B-001U0?Description=3080&cm_re=3080-_-9SIACY7F5G3938-_-Product
#
#
#
#
#
#
# CLX SET Gaming Desktop - Liquid Cooled AMD Ryzen 9 5900X 3.7GHz 12-Core Processor, 32GB DDR4 Memory, GeForce RTX 3080 Ti 12GB GDDR6X Graphics, 500GB SSD, 4TB HDD, WiFi, Windows 10 Home 64-bit
# $5111
# https://www.newegg.ca/clx-tgmsetrth1671bm/p/3D5-000B-002C5?Description=3080&cm_re=3080-_-9SIACY7FAT1231-_-Product
#
#
#
#
#
#
# CLX SET VR-Ready Gaming Desktop - Liquid Cooled AMD Ryzen 9 5950X 3.4Ghz 16-Core Processor, 64GB DDR4 Memory, GeForce RTX 3080 10GB GDDR6X Graphics, 1TB SSD, 6TB HDD, WiFi, Windows 10 Home 64-bit
# $5466
# https://www.newegg.ca/clx-tgmsetrth0b26bm/p/3D5-000B-001U8?Description=3080&cm_re=3080-_-9SIACY7F5G3940-_-Product
#
#
#
#
#
#
# IPASON - Gaming Desktop - 10900K 10 Core up to 5.3GHz - RTX 3080 10GB - 1TB NVMe SSD -G.SKILL Trident Z RGB 32GB(16*2) DDR4 3600MHz - Windows 10 home - Gaming PC
# $5480
# https://www.newegg.ca/p/3D5-001U-00020?Description=3080&cm_re=3080-_-3D5-001U-00020-_-Product
#
#
#
#
#
#
# CLX SET Gaming Desktop - AMD Ryzen 9 3950X Processor, 64GB DDR4 Memory, NVIDIA GeForce RTX 3080 Graphics, 1 TB SSD, 6 TB HDD, WiFi, Windows 10 Home 64-bit
# $5512
# https://www.newegg.ca/clx-tgmsetrth0912bm/p/3D5-000B-00145?Description=3080&cm_re=3080-_-9SIACY7F5G3930-_-Product
#
#
#
#
#
#
# CLX SET Gaming Desktop - Intel Core i9 10940X Processor, 32GB DDR4 Memory, NVIDIA GeForce RTX 3080 Graphics, 480 GB SSD, 3 TB HDD, WiFi, Windows 10 Home 64-bit
# $5588
# https://www.newegg.ca/clx-tgmsetrth0915br/p/3D5-000B-00156?Description=3080&cm_re=3080-_-9SIACY7F5G3904-_-Product
#
#
#
#
#
#
# ABS Legend Gaming PC - AMD R9 5950X - EVGA GeForce RTX 3080 Ti FTW3 - Corsair Vengeance RGB 32GB DDR4 3600MHz - 2TB Intel M.2 NVMe SSD - Corsair iCUE H115i Elite 280MM AIO - Windows 10 Pro 64-bit
# $5599
# https://www.newegg.ca/abs-ala258/p/N82E16883360172?Description=3080&cm_re=3080-_-83-360-172-_-Product
#
#
#
#
#
#
# CLX SET Gaming Desktop - Intel Core i9 10920X Processor, 64GB DDR4 Memory, NVIDIA GeForce RTX 3080 Graphics, 1 TB SSD, 6 TB HDD, WiFi, Windows 10 Home 64-bit
# $5854
# https://www.newegg.ca/clx-tgmsetrth0917bm/p/3D5-000B-00164?Description=3080&cm_re=3080-_-9SIACY7F5G3912-_-Product
#
#
#
#
#
#
# ABS Legend Gaming PC - Intel i9 11900K - ASUS ROG STRIX GeForce RTX 3080 Ti - G.Skill TridentZ RGB 32GB DDR4 3200MHz - 1TB AORUS GEN4 M.2 NVMe SSD - EVGA CLC 280MM RGB AIO - Windows 10 Pro 64-bit
# $5899
# https://www.newegg.ca/abs-ali538/p/N82E16883360143?Description=3080&cm_re=3080-_-83-360-143-_-Product
#
#
#
#
#
#
# CLX SET Gaming Desktop - Intel Core i9 10940X Processor, 64GB DDR4 Memory, NVIDIA GeForce RTX 3080 Graphics, 1 TB SSD, 6 TB HDD, WiFi, Windows 10 Home 64-bit
# $6070
# https://www.newegg.ca/clx-tgmsetrth0918bm/p/3D5-000B-00168?Description=3080&cm_re=3080-_-9SIACY7F5G3916-_-Product

# %% [markdown]
# ---
